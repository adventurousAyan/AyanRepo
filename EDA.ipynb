# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data1 = pd.read_csv("./datasets/Plant_1_Generation_Data.csv")
data2 = pd.read_csv("./datasets/Plant_1_Weather_Sensor_Data.csv")

# %%
print(data1.shape)
print(data2.shape)
# Out:
# (68778, 7)
# (3182, 6)

# %%
data1.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
data1.tail()
# Out:
#               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 68773  17-06-2020 23:45   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774  17-06-2020 23:45   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775  17-06-2020 23:45   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776  17-06-2020 23:45   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777  17-06-2020 23:45   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 68773     5967.000    7287002.0
# 68774     5147.625    7028601.0
# 68775     5819.000    7251204.0
# 68776     5817.000    6583369.0
# 68777     5910.000    7363272.0

# %%
data2.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
data2.tail()
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 3177  2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178  2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179  2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180  2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181  2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION
# 3177           21.480377          0.0
# 3178           21.389024          0.0
# 3179           20.709211          0.0
# 3180           20.734963          0.0
# 3181           20.427972          0.0

# %%
data1.describe()
# Out:
#         PLANT_ID      DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD
# count    68778.0  68778.000000  68778.000000  68778.000000  6.877800e+04
# mean   4135001.0   3147.426211    307.802752   3295.968737  6.978712e+06
# std          0.0   4036.457169    394.396439   3145.178309  4.162720e+05
# min    4135001.0      0.000000      0.000000      0.000000  6.183645e+06
# 25%    4135001.0      0.000000      0.000000      0.000000  6.512003e+06
# 50%    4135001.0    429.000000     41.493750   2658.714286  7.146685e+06
# 75%    4135001.0   6366.964286    623.618750   6274.000000  7.268706e+06
# max    4135001.0  14471.125000   1410.950000   9163.000000  7.846821e+06

# %%
data1.groupby(['DATE_TIME'])['SOURCE_KEY'].count()
# Out:
# DATE_TIME
# 01-06-2020 00:00    22
# 01-06-2020 00:15    22
# 01-06-2020 00:30    22
# 01-06-2020 00:45    22
# 01-06-2020 01:00    22
#                     ..
# 31-05-2020 22:45    22
# 31-05-2020 23:00    22
# 31-05-2020 23:15    22
# 31-05-2020 23:30    22
# 31-05-2020 23:45    22
# Name: SOURCE_KEY, Length: 3158, dtype: int64

# %%
data2.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
data1.dtypes
# Out:
# DATE_TIME       object
# PLANT_ID         int64
# SOURCE_KEY      object
# DC_POWER       float64
# AC_POWER       float64
# DAILY_YIELD    float64
# TOTAL_YIELD    float64
# dtype: object

# %%
data2.dtypes
# Out:
# DATE_TIME               object
# PLANT_ID                 int64
# SOURCE_KEY              object
# AMBIENT_TEMPERATURE    float64
# MODULE_TEMPERATURE     float64
# IRRADIATION            float64
# dtype: object

# %%
data1.isnull().sum()
# Out:
# DATE_TIME      0
# PLANT_ID       0
# SOURCE_KEY     0
# DC_POWER       0
# AC_POWER       0
# DAILY_YIELD    0
# TOTAL_YIELD    0
# dtype: int64

# %%
data1.nunique()
# Out:
# DATE_TIME       3158
# PLANT_ID           1
# SOURCE_KEY        22
# DC_POWER       32909
# AC_POWER       32686
# DAILY_YIELD    29900
# TOTAL_YIELD    37267
# dtype: int64

# %%
#data1['DATE_TIME'] = datetime(data1['DATE_TIME'])
#data1['DATE_TIME'] = data1['DATE_TIME'].strptime('%Y-%m-%d %H:%M:%S')
data1['DATE_TIME'] = pd.to_datetime(data1['DATE_TIME'], infer_datetime_format=True)
data2['DATE_TIME'] = pd.to_datetime(data2['DATE_TIME'], infer_datetime_format=True)
data1.dtypes
# Out:
# DATE_TIME      datetime64[ns]
# PLANT_ID                int64
# SOURCE_KEY             object
# DC_POWER              float64
# AC_POWER              float64
# DAILY_YIELD           float64
# TOTAL_YIELD           float64
# dtype: object

# %%
data1.tail()
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 68773 2020-06-17 23:45:00   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774 2020-06-17 23:45:00   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775 2020-06-17 23:45:00   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776 2020-06-17 23:45:00   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777 2020-06-17 23:45:00   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 68773     5967.000    7287002.0
# 68774     5147.625    7028601.0
# 68775     5819.000    7251204.0
# 68776     5817.000    6583369.0
# 68777     5910.000    7363272.0

# %%
df = data1.groupby(['SOURCE_KEY']).agg(mean_daily_yield = ('DAILY_YIELD',np.mean), mean_total_yield = ('TOTAL_YIELD', np.mean)\
                                      , mean_ac_power = ('AC_POWER', np.mean), mean_dc_power = ('DC_POWER', np.mean) )
df.reset_index()
df.sort_values(['mean_ac_power', 'mean_dc_power'], ascending = [False,False])
# Out:
#                  mean_daily_yield  mean_total_yield  mean_ac_power  \
# SOURCE_KEY
# adLQvlD726eNBSB       3399.686281      6.402452e+06     319.693862
# 1IF53ai7Xc0U56Y       3356.882104      6.313086e+06     315.488026
# 3PZuoBAID5Wc2HD       3356.856357      7.117013e+06     314.967354
# McdE0feGgRqW7Ca       3321.935705      7.287580e+06     314.046321
# VHMLBKoKgIrUVDU       3407.255472      7.335465e+06     313.900096
# iCRJl6heRkivqQ3       3314.642658      7.305670e+06     312.540320
# uHbuxQJl8lW7ozc       3311.003159      7.166283e+06     312.467844
# ZnxXDlPa8U1GXgE       3378.012862      6.650663e+06     312.346427
# zVJPv84UY57bAof       3297.805678      7.243085e+06     311.676665
# YxYtjZvoooNbGkE       3300.900825      7.307357e+06     310.930334
# wCURE6d3bPkepu2       3256.768423      6.909718e+06     310.064044
# pkci93gMrogZuBj       3283.072516      7.295685e+06     309.670213
# rGa61gmuvPhdLxV       3272.289839      7.237456e+06     309.345658
# WRmjgnKYAwPKWDb       3290.830582      7.155458e+06     308.575465
# zBIq5rxdHJRwDNY       3231.159950      6.464955e+06     307.925344
# sjndEbLyjtCKgGv       3245.007129      7.143000e+06     307.912265
# ZoEaEvLYb1n2sOq       3251.780504      7.223575e+06     306.980623
# z9Y9gH1T5YWrNuG       3260.837944      7.133928e+06     306.492026
# 7JYdWkrLSPkdwr4       3325.810327      7.728914e+06     306.385671
# ih0vzX44oOqAx2f       3273.169050      6.309606e+06     302.962438
# 1BY6WEcLGh8j5v7       3230.658151      6.377464e+06     281.124073
# bvBOhCH3iADSZry       3146.858362      6.432819e+06     276.778938
#
#                  mean_dc_power
# SOURCE_KEY
# adLQvlD726eNBSB    3269.567669
# 1IF53ai7Xc0U56Y    3226.336768
# 3PZuoBAID5Wc2HD    3221.015673
# McdE0feGgRqW7Ca    3211.307245
# VHMLBKoKgIrUVDU    3210.102563
# iCRJl6heRkivqQ3    3196.074675
# uHbuxQJl8lW7ozc    3195.316080
# ZnxXDlPa8U1GXgE    3194.059104
# zVJPv84UY57bAof    3187.236622
# YxYtjZvoooNbGkE    3179.492570
# wCURE6d3bPkepu2    3170.704424
# pkci93gMrogZuBj    3166.599439
# rGa61gmuvPhdLxV    3163.240929
# WRmjgnKYAwPKWDb    3155.384433
# zBIq5rxdHJRwDNY    3148.590013
# sjndEbLyjtCKgGv    3148.270450
# ZoEaEvLYb1n2sOq    3139.009808
# z9Y9gH1T5YWrNuG    3134.037738
# 7JYdWkrLSPkdwr4    3132.891955
# ih0vzX44oOqAx2f    3097.714161
# 1BY6WEcLGh8j5v7    2873.720981
# bvBOhCH3iADSZry    2828.998291

# %%
plt.figure(figsize=(12,12))
sns.barplot(x = df.index, y = 'mean_daily_yield', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.barplot(x = df.index, y = 'mean_total_yield', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(25,25))
sns.set(style="whitegrid")
sns.boxplot(x=data1.SOURCE_KEY, y=data1.DAILY_YIELD, data=data1)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(25,25))
sns.set(style="whitegrid")
sns.boxplot(x=data1.SOURCE_KEY, y=data1.TOTAL_YIELD, data=data1)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(25,25))
sns.set(style="whitegrid")
sns.scatterplot(x='mean_daily_yield', y='mean_total_yield', hue=df.index, data=df)
plt.xticks(rotation=45)
plt.show()

# %%
data1['DATE'] = data1['DATE_TIME'].dt.strftime('%Y-%m-%d')
data1.tail()
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 68773 2020-06-17 23:45:00   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774 2020-06-17 23:45:00   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775 2020-06-17 23:45:00   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776 2020-06-17 23:45:00   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777 2020-06-17 23:45:00   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD        DATE
# 68773     5967.000    7287002.0  2020-06-17
# 68774     5147.625    7028601.0  2020-06-17
# 68775     5819.000    7251204.0  2020-06-17
# 68776     5817.000    6583369.0  2020-06-17
# 68777     5910.000    7363272.0  2020-06-17

# %%
df2 = data1.groupby(['DATE','SOURCE_KEY']).agg(mean_daily_yield = ('DAILY_YIELD',np.mean), mean_total_yield = ('TOTAL_YIELD', np.mean)\
                                      , mean_ac_power = ('AC_POWER', np.mean), mean_dc_power = ('DC_POWER', np.mean) )
df2 = df2.reset_index()
df2.sort_values(['mean_ac_power', 'mean_dc_power'], ascending = [False,False], inplace= True)
df2.head(50)
# Out:
#            DATE       SOURCE_KEY  mean_daily_yield  mean_total_yield  \
# 142  2020-05-21  adLQvlD726eNBSB       3433.049436      6.319147e+06
# 140  2020-05-21  ZnxXDlPa8U1GXgE       3345.848997      6.569456e+06
# 133  2020-05-21  1IF53ai7Xc0U56Y       3358.778571      6.230853e+06
# 134  2020-05-21  3PZuoBAID5Wc2HD       3369.586090      7.034925e+06
# 137  2020-05-21  VHMLBKoKgIrUVDU       3442.247845      7.254004e+06
# 145  2020-05-21  ih0vzX44oOqAx2f       3245.912364      6.231195e+06
# 138  2020-05-21  WRmjgnKYAwPKWDb       3292.650125      7.075038e+06
# 135  2020-05-21  7JYdWkrLSPkdwr4       3356.849323      7.649327e+06
# 325  2020-05-29  uHbuxQJl8lW7ozc       3128.197802      7.148803e+06
# 320  2020-05-29  iCRJl6heRkivqQ3       3079.139744      7.288139e+06
# 323  2020-05-29  rGa61gmuvPhdLxV       3103.097436      7.219951e+06
# 322  2020-05-29  pkci93gMrogZuBj       3115.147344      7.278411e+06
# 329  2020-05-29  zVJPv84UY57bAof       3083.313919      7.225578e+06
# 312  2020-05-29  McdE0feGgRqW7Ca       3100.808974      7.270089e+06
# 326  2020-05-29  wCURE6d3bPkepu2       3060.368864      6.892781e+06
# 324  2020-05-29  sjndEbLyjtCKgGv       3046.897711      7.125950e+06
# 315  2020-05-29  YxYtjZvoooNbGkE       3034.548260      7.289432e+06
# 327  2020-05-29  z9Y9gH1T5YWrNuG       3036.299908      7.117390e+06
# 317  2020-05-29  ZoEaEvLYb1n2sOq       3020.267491      7.206542e+06
# 328  2020-05-29  zBIq5rxdHJRwDNY       2944.045238      6.446885e+06
# 136  2020-05-21  McdE0feGgRqW7Ca       5765.393205      7.206874e+06
# 153  2020-05-21  zVJPv84UY57bAof       5766.879194      7.162955e+06
# 149  2020-05-21  uHbuxQJl8lW7ozc       5706.153352      7.085825e+06
# 318  2020-05-29  adLQvlD726eNBSB       5448.462609      6.384472e+06
# 147  2020-05-21  rGa61gmuvPhdLxV       5629.181648      7.158271e+06
# 151  2020-05-21  z9Y9gH1T5YWrNuG       5721.496923      7.054992e+06
# 144  2020-05-21  iCRJl6heRkivqQ3       5688.897143      7.225303e+06
# 148  2020-05-21  sjndEbLyjtCKgGv       5628.479267      7.063751e+06
# 309  2020-05-29  1IF53ai7Xc0U56Y       5392.308518      6.295365e+06
# 139  2020-05-21  YxYtjZvoooNbGkE       5625.805110      7.226926e+06
# 146  2020-05-21  pkci93gMrogZuBj       5638.597033      7.215845e+06
# 150  2020-05-21  wCURE6d3bPkepu2       5594.153846      6.829917e+06
# 152  2020-05-21  zBIq5rxdHJRwDNY       5615.329725      6.386486e+06
# 310  2020-05-29  3PZuoBAID5Wc2HD       5375.232059      7.099354e+06
# 313  2020-05-29  VHMLBKoKgIrUVDU       5341.574614      7.318229e+06
# 141  2020-05-21  ZoEaEvLYb1n2sOq       5534.391777      7.144610e+06
# 316  2020-05-29  ZnxXDlPa8U1GXgE       5318.925973      6.633235e+06
# 311  2020-05-29  7JYdWkrLSPkdwr4       5235.595993      7.712064e+06
# 314  2020-05-29  WRmjgnKYAwPKWDb       5259.032361      7.138120e+06
# 321  2020-05-29  ih0vzX44oOqAx2f       5192.026660      6.292362e+06
# 132  2020-05-21  1BY6WEcLGh8j5v7       5266.323535      6.303622e+06
# 308  2020-05-29  1BY6WEcLGh8j5v7       4943.109457      6.362753e+06
# 143  2020-05-21  bvBOhCH3iADSZry       5131.888059      6.360226e+06
# 319  2020-05-29  bvBOhCH3iADSZry       4811.151962      6.418441e+06
# 186  2020-05-23  adLQvlD726eNBSB       4501.103866      6.333452e+06
# 177  2020-05-23  1IF53ai7Xc0U56Y       4444.868646      6.244979e+06
# 180  2020-05-23  McdE0feGgRqW7Ca       4390.253852      7.220379e+06
# 178  2020-05-23  3PZuoBAID5Wc2HD       4434.030765      7.049050e+06
# 196  2020-05-23  zBIq5rxdHJRwDNY       4424.346643      6.400231e+06
# 188  2020-05-23  iCRJl6heRkivqQ3       4401.453117      7.238994e+06
#
#      mean_ac_power  mean_dc_power
# 142     543.992180    5566.565915
# 140     534.425700    5468.144319
# 133     532.492074    5448.201441
# 134     532.384486    5447.268045
# 137     523.499483    5356.598338
# 145     519.598855    5316.257331
# 138     519.057678    5310.063680
# 135     514.012235    5259.042057
# 325     512.862436    5247.685623
# 320     508.044139    5197.887638
# 323     508.037390    5197.642033
# 322     507.699725    5194.099084
# 329     507.092573    5188.095788
# 312     505.985513    5176.431502
# 326     504.412619    5160.551282
# 324     498.109973    5095.517033
# 315     498.084771    5095.194597
# 327     497.218782    5086.456960
# 317     496.805192    5082.299451
# 328     488.240833    4993.934799
# 136     477.741159    4889.382088
# 153     477.318875    4884.744744
# 149     473.523115    4845.509561
# 318     470.343880    4812.090627
# 147     469.312203    4801.867802
# 151     468.462423    4793.590824
# 144     468.276923    4791.407417
# 148     467.762447    4786.483626
# 309     466.423910    4771.906942
# 139     465.135121    4759.405586
# 146     465.110991    4759.296007
# 150     464.018498    4747.916850
# 152     463.529038    4742.542582
# 310     463.402523    4741.014588
# 313     461.265107    4719.250671
# 141     459.539231    4701.629176
# 316     459.005902    4695.838196
# 311     451.761595    4621.559943
# 314     451.630173    4620.151157
# 321     448.614898    4589.032277
# 132     434.202042    4441.178480
# 308     427.992731    4377.134859
# 143     425.999690    4357.206190
# 319     420.573662    4299.957193
# 186     394.488911    4036.147806
# 177     390.183608    3991.954655
# 180     389.342673    3983.228652
# 178     389.267369    3982.416734
# 196     387.460153    3963.891720
# 188     387.368660    3962.971375

# %%
df2.index
# Out:
# MultiIndex([('2020-05-15', '1BY6WEcLGh8j5v7'),
#             ('2020-05-15', '1IF53ai7Xc0U56Y'),
#             ('2020-05-15', '3PZuoBAID5Wc2HD'),
#             ('2020-05-15', '7JYdWkrLSPkdwr4'),
#             ('2020-05-15', 'McdE0feGgRqW7Ca'),
#             ('2020-05-15', 'VHMLBKoKgIrUVDU'),
#             ('2020-05-15', 'WRmjgnKYAwPKWDb'),
#             ('2020-05-15', 'YxYtjZvoooNbGkE'),
#             ('2020-05-15', 'ZnxXDlPa8U1GXgE'),
#             ('2020-05-15', 'ZoEaEvLYb1n2sOq'),
#             ...
#             ('2020-06-17', 'iCRJl6heRkivqQ3'),
#             ('2020-06-17', 'ih0vzX44oOqAx2f'),
#             ('2020-06-17', 'pkci93gMrogZuBj'),
#             ('2020-06-17', 'rGa61gmuvPhdLxV'),
#             ('2020-06-17', 'sjndEbLyjtCKgGv'),
#             ('2020-06-17', 'uHbuxQJl8lW7ozc'),
#             ('2020-06-17', 'wCURE6d3bPkepu2'),
#             ('2020-06-17', 'z9Y9gH1T5YWrNuG'),
#             ('2020-06-17', 'zBIq5rxdHJRwDNY'),
#             ('2020-06-17', 'zVJPv84UY57bAof')],
#            names=['DATE', 'SOURCE_KEY'], length=748)

# %%
df2.index.get_level_values(1)
# Out:
# Index(['adLQvlD726eNBSB', 'ZnxXDlPa8U1GXgE', '1IF53ai7Xc0U56Y',
#        '3PZuoBAID5Wc2HD', 'VHMLBKoKgIrUVDU', 'ih0vzX44oOqAx2f',
#        'WRmjgnKYAwPKWDb', '7JYdWkrLSPkdwr4', 'uHbuxQJl8lW7ozc',
#        'iCRJl6heRkivqQ3',
#        ...
#        '1BY6WEcLGh8j5v7', 'ih0vzX44oOqAx2f', '7JYdWkrLSPkdwr4',
#        '1BY6WEcLGh8j5v7', 'bvBOhCH3iADSZry', 'bvBOhCH3iADSZry',
#        '1BY6WEcLGh8j5v7', 'bvBOhCH3iADSZry', '1BY6WEcLGh8j5v7',
#        'bvBOhCH3iADSZry'],
#       dtype='object', name='SOURCE_KEY', length=748)

# %%
plt.figure(figsize=(30,30))
sns.barplot(x = df2.DATE, y = df2.mean_ac_power, data=df2, hue=df2.SOURCE_KEY)
plt.xticks(rotation=45)
plt.show()
